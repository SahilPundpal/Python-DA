# %% [markdown]
# #### Functions in Python
# Video Outline:
# 1. Introduction to Functions
# 2. Defining Functions
# 3. Calling Functions
# 4. Function Parameters
# 5. Default Parameters
# 6. Variable-Length Arguments
# 7. Return Statement

# %% [markdown]
# ##### Introduction to Functions
# Definition:
#
# A function is a block of code that performs a specific task.
# Functions help in organizing code, reusing code, and improving readability.

# %%
## syntax
def function_name(parameters):
    """Docstring"""
    # Function body
    return expression

# %%
## why functions?
num=24
if num%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is even

# %%
def even_or_odd(num):
    """This function finds even or odd"""
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
## Call this function
even_or_odd(24)
even_or_odd(13)
# Out:
# the number is even
# the number is odd

# %%
## function with multiple parameters

def add(a,b):
    return a+b

result=add(2,4)
print(result)
print(add(3,5))
# Out:
# 6
# 8

# %%
## Default Parameters

def greet(name):
    print(f"Hello {name} Welcome To the paradise" ,end=" ")
    print(f"and have a good vacation dear {name}")

greet("Krish")
greet("XYZ")
# Out:
# Hello Krish Welcome To the paradise and have a good vacation dear Krish
# Hello XYZ Welcome To the paradise and have a good vacation dear XYZ

# %%
def greet(name="Guest"):
    print(f"Hello {name} Welcome To the paradise")

greet("Krish")
# Out:
# Hello Krish Welcome To the paradise

# %%
### Variable Length Arguments
## Positional And Keywords arguments

def print_numbers(*krish):
    for number in krish:
        print(number,end=" ")
    print()


'''  
What does *krish mean?
It means:
Collect all positional arguments into a tuple.

Without *
def print_numbers(krish):
    print(krish)

Now the function expects exactly one argument.
print_numbers(1)
Works.
print_numbers(1,2,3)
Gives an error:
TypeError:
print_numbers() takes 1 positional argument but 3 were given

With *
def print_numbers(*krish):
    print(krish)

Now it accepts any number of positional arguments.
print_numbers()
Output: -> ()

print_numbers(10)
Output:-> (10,)

print_numbers(10,20,30)
Output:-> (10, 20, 30)

'''

# %%
print_numbers(1,2,3,4,5,6,7,8,"Krish")
lst=[1,2,34,45,34,56,867,98]
print_numbers(lst,[1,52,346,346.35,34,786])
print_numbers(([1,52,346,346.35,34,786]))
# Out:
# 1 2 3 4 5 6 7 8 Krish
# [1, 2, 34, 45, 34, 56, 867, 98] [1, 52, 346, 346.35, 34, 786]
# [1, 52, 346, 346.35, 34, 786]

# %%
## Positional arguments
def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"Krish")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Krish

# %%
### Keywords Arguments

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(name="Krish",age="32",country="India")

'''  
This is the counterpart of *args.
*args → collects positional arguments into a tuple.
**kwargs → collects keyword arguments into a dictionary.


When you call
print_details(
    name="Krish",
    age="32",
    country="India"
)

Python internally creates this dictionary:
kwargs = {
    "name": "Krish",
    "age": "32",
    "country": "India"
}
'''
# Out:
# name:Krish
# age:32
# country:India
# '  \nThis is the counterpart of *args.\n*args → collects positional arguments into a tuple.\n**kwargs → collects keyword arguments into a dictionary.\n\n\nWhen you call\nprint_details(\n    name="Krish",\n    age="32",\n    country="India"\n)\n\nPython internally creates this dictionary:\nkwargs = {\n    "name": "Krish",\n    "age": "32",\n    "country": "India"\n}\n'

# %%
def print_details(*args,**kwargs):
    for val in args:
        print(f" Positional arument :{val}")
    
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(1,2,3,4,"Krish",name="Krish",age="32",country="India")

'''  
Important Rule

When defining a function, *args must come before **kwargs:
def func(*args, **kwargs):
    pass

    
❌ This is invalid:
def func(**kwargs, *args):   # SyntaxError
    pass

because Python first collects all positional arguments into args, and then collects all keyword arguments into kwargs.

'''
# Out:
#  Positional arument :1
#  Positional arument :2
#  Positional arument :3
#  Positional arument :4
#  Positional arument :Krish
# name:Krish
# age:32
# country:India

# %%
### Return statements
def multiply(a,b):
    return a*b

multiply(2,3)
# Out:
# 6

# %%
### Return multiple parameters
def multiply(a,b):
    return a,b,a*b

multiply(2,3)
# Out:
# (2, 3, 6)
