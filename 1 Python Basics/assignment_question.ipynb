# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a=int(input())
print(a)
# Out:
# 89

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a=int(input())
if(a>0):
  print("POS")
elif(a<0):
  print("NEG")
else:
  print("zero")
# Out:
# zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a=int(input())
b=int(input())
c=int(input())

if(a>b):
  if(a>c):
    print(a)
  else:
    print(c)
else:
  if(b>c):
    print(b)
  else:
    print(c)
# Out:
# -2

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
a=int(input())
ans=1
for i in range(1, a+1):
  ans=ans*i
print(ans)
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a=int(input())
b=float(input())
c=str(input())
d=bool(input())

print(a, "and it's type is ", type(a))
print(b, "and it's type is ", type(b))
print(c, "and it's type is ", type(c))
print(d, "and it's type is ", type(d))
# Out:
# 5 and it's type is  <class 'int'>
# 1.2 and it's type is  <class 'float'>
# sahil and it's type is  <class 'str'>
# True and it's type is  <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
#a=input()
#b=input()

#c=a
#a=b
#b=c
#print(a, b)

a = 5
b = 10
print(f"Before swap: a = {a}, b = {b}")

# Swapping
a, b = b, a
print(f"After swap: a = {a}, b = {b}")
# Out:
# Before swap: a = 5, b = 10
# After swap: a = 10, b = 5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
a=int(input())
b=(a*(9/5) + 32)
c=round(a*(9/5) + 32)
print(a," in fahrenheit is ", b)
print(a," in fahrenheit is ", c)
# Out:
# 37  in fahrenheit is  98.60000000000001
# 37  in fahrenheit is  99

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a=str(input())
b=str(input())

c=a+" "+b
print(c)
# Out:
# adkhd sahil

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
# Solution
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float") #we can also write this as print(var, "is a float")
else:
    print(f"{var} is not a float")
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a=int(input())
b=int(input())

print(f"Add of {a} and {b} is {a + b}")
print(f"Sub of {a} and {b} is {a - b}")
print(f"Mul of {a} and {b} is {a * b}")
print(f"Div of {a} and {b} is {a / b}")
print(f"Reaminder of {a} modulo {b} is {a % b}")
# Out:
# Add of 12 and 5 is 17
# Sub of 12 and 5 is 7
# Mul of 12 and 5 is 60
# Div of 12 and 5 is 2.4
# Reaminder of 12 modulo 5 is 2

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
# Solution
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
# Out:
# 2.4.4

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.3 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 1.4 MB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.0 MB 1.5 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/4.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.3 MB/s  0:00:02
# ...

# %%
# !pip install html5lib

# %%
# !pip install beautifulsoup4

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
